# %% [markdown]
# ##  A. read movies data set csv file and print first and last 5 rows of the data frame

# %%
import pandas as pd
import numpy as np
df=pd.read_csv('movies_metadata.csv')
df.head()
# Out:
# C:\Users\mutturaj\AppData\Local\Temp\ipykernel_10048\2253848491.py:3: DtypeWarning: Columns (10) have mixed types. Specify dtype option on import or set low_memory=False.
#   df=pd.read_csv('movies_metadata.csv')
#    adult                              belongs_to_collection    budget  \
# 0  False  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1  False                                                NaN  65000000
# 2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3  False                                                NaN  16000000
# 4  False  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
# ...

# %%
df.tail()
# Out:
#        adult belongs_to_collection budget  \
# 45461  False                   NaN      0
# 45462  False                   NaN      0
# 45463  False                   NaN      0
# 45464  False                   NaN      0
# 45465  False                   NaN      0
#
#                                                   genres  \
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# 45463  [{'id': 28, 'name': 'Action'}, {'id': 18, 'nam...
# 45464                                                 []
# 45465                                                 []
#
#                                    homepage      id    imdb_id  \
# 45461  http://www.imdb.com/title/tt6209470/  439050  tt6209470
# 45462                                   NaN  111109  tt2028550
# 45463                                   NaN   67758  tt0303758
# 45464                                   NaN  227506  tt0008536
# ...

# %% [markdown]
# ## B. print over all statistics of the data frame

# %%
df.describe()
# Out:
#             revenue       runtime  vote_average    vote_count
# count  4.546000e+04  45203.000000  45460.000000  45460.000000
# mean   1.120935e+07     94.128199      5.618207    109.897338
# std    6.433225e+07     38.407810      1.924216    491.310374
# min    0.000000e+00      0.000000      0.000000      0.000000
# 25%    0.000000e+00     85.000000      5.000000      3.000000
# 50%    0.000000e+00     95.000000      6.000000     10.000000
# 75%    0.000000e+00    107.000000      6.800000     34.000000
# max    2.787965e+09   1256.000000     10.000000  14075.000000

# %% [markdown]
# ## c. print data types of all the attributes

# %%
df.dtypes
# Out:
# adult                     object
# belongs_to_collection     object
# budget                    object
# genres                    object
# homepage                  object
# id                        object
# imdb_id                   object
# original_language         object
# original_title            object
# overview                  object
# popularity                object
# poster_path               object
# production_companies      object
# production_countries      object
# release_date              object
# revenue                  float64
# runtime                  float64
# spoken_languages          object
# status                    object
# tagline                   object
# title                     object
# video                     object
# vote_average             float64
# vote_count               float64
# dtype: object

# %% [markdown]
# ##  D.check wehther the data frame contains null values or not

# %%
df.isnull().any().any()
# Out:
# True

# %% [markdown]
# ## E. count null values of the columns

# %%
df.isnull().sum()
# Out:
# adult                        0
# belongs_to_collection    40972
# budget                       0
# genres                       0
# homepage                 37684
# id                           0
# imdb_id                     17
# original_language           11
# original_title               0
# overview                   954
# popularity                   5
# poster_path                386
# production_companies         3
# production_countries         3
# release_date                87
# revenue                      6
# runtime                    263
# spoken_languages             6
# status                      87
# tagline                  25054
# title                        6
# video                        6
# vote_average                 6
# vote_count                   6
# dtype: int64

# %% [markdown]
# ## F.replace all the null values of the data frame with TRUE or FALSE

# %%
df.isnull()
# Out:
#        adult  belongs_to_collection  budget  genres  homepage     id  imdb_id  \
# 0      False                  False   False   False     False  False    False
# 1      False                   True   False   False      True  False    False
# 2      False                  False   False   False      True  False    False
# 3      False                   True   False   False      True  False    False
# 4      False                  False   False   False      True  False    False
# ...      ...                    ...     ...     ...       ...    ...      ...
# 45461  False                   True   False   False     False  False    False
# 45462  False                   True   False   False      True  False    False
# 45463  False                   True   False   False      True  False    False
# 45464  False                   True   False   False      True  False    False
# 45465  False                   True   False   False      True  False    False
#
# ...

# %% [markdown]
# ## G. count unique values in each attribute of the data frame

# %%
df.nunique()
# Out:
# adult                        5
# belongs_to_collection     1698
# budget                    1226
# genres                    4069
# homepage                  7673
# id                       45436
# imdb_id                  45417
# original_language           92
# original_title           43373
# overview                 44307
# popularity               44176
# poster_path              45024
# production_companies     22708
# production_countries      2393
# release_date             17336
# revenue                   6863
# runtime                    353
# spoken_languages          1931
# status                       6
# tagline                  20283
# title                    42277
# video                        2
# vote_average                92
# vote_count                1820
# dtype: int64

# %% [markdown]
# ## H. count of each unique value in the status attribute

# %%
df.status.value_counts()
# Out:
# Released           45014
# Rumored              230
# Post Production       98
# In Production         20
# Planned               15
# Canceled               2
# Name: status, dtype: int64

# %% [markdown]
# ##  J.get the columns of the data frame

# %%
df.columns
# Out:
# Index(['adult', 'belongs_to_collection', 'budget', 'genres', 'homepage', 'id',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'revenue', 'runtime',
#        'spoken_languages', 'status', 'tagline', 'title', 'video',
#        'vote_average', 'vote_count'],
#       dtype='object')

# %% [markdown]
# ##  K.get the information of the data frame

# %%
result=df.info()
print("Details of the dataframe")
print(result)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45466 entries, 0 to 45465
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45466 non-null  object
#  1   belongs_to_collection  4494 non-null   object
#  2   budget                 45466 non-null  object
#  3   genres                 45466 non-null  object
#  4   homepage               7782 non-null   object
#  5   id                     45466 non-null  object
#  6   imdb_id                45449 non-null  object
#  7   original_language      45455 non-null  object
#  8   original_title         45466 non-null  object
#  9   overview               44512 non-null  object
#  10  popularity             45461 non-null  object
#  11  poster_path            45080 non-null  object
#  12  production_companies   45463 non-null  object
#  13  production_countries   45463 non-null  object
# ...

# %% [markdown]
# ## L.get the details of the third movie of the dataframe

# %%
third_movie=df.iloc[2]
print("details of third movie:")
print(third_movie)
# Out:
# details of third movie:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %% [markdown]
# ## M.count the number of rows and columns of the dataframe

# %%
df.shape
# Out:
# (45466, 24)

# %% [markdown]
# ## N.get the details of the columns title & of the data frame

# %%
df[['title','genres']]
# Out:
#                              title  \
# 0                        Toy Story
# 1                          Jumanji
# 2                 Grumpier Old Men
# 3                Waiting to Exhale
# 4      Father of the Bride Part II
# ...                            ...
# 45461                       Subdue
# 45462          Century of Birthing
# 45463                     Betrayal
# 45464             Satan Triumphant
# 45465                     Queerama
#
#                                                   genres
# 0      [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1      [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2      [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3      [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                         [{'id': 35, 'name': 'Comedy'}]
# ...                                                  ...
# 45461  [{'id': 18, 'name': 'Drama'}, {'id': 10751, 'n...
# 45462                      [{'id': 18, 'name': 'Drama'}]
# ...

# %% [markdown]
# ##  O.get the details of the movie with title 'Grumpier old men'

# %%
df=df.set_index("title")
result=df.loc['Grumpier Old Men']
#print("details of the movie grumpier old men")
print(result)
# Out:
# adult                                                                False
# belongs_to_collection    {'id': 119050, 'name': 'Grumpy Old Men Collect...
# budget                                                                   0
# genres                   [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# homepage                                                               NaN
# id                                                                   15602
# imdb_id                                                          tt0113228
# original_language                                                       en
# original_title                                            Grumpier Old Men
# overview                 A family wedding reignites the ancient feud be...
# popularity                                                         11.7129
# poster_path                               /6ksm1sjKMFLbO7UY2i6G1ju9SML.jpg
# ...

# %% [markdown]
# ##  P.create a smaller data frame with a subset of all features

# %%
small_df=df[["release_date","budget","revenue","runtime"]]
#print("smaller dataframe:")
print(small_df.head())
# Out:
#                             release_date    budget      revenue  runtime
# title
# Toy Story                     1995-10-30  30000000  373554033.0     81.0
# Jumanji                       1995-12-15  65000000  262797249.0    104.0
# Grumpier Old Men              1995-12-22         0          0.0    101.0
# Waiting to Exhale             1995-12-22  16000000   81452156.0    127.0
# Father of the Bride Part II   1995-02-10         0   76578911.0    106.0

# %% [markdown]
# ## Q.sort the data frame based on release_date

# %%
result=small_df.sort_values('release_date')
#print("data frame based on release date:")
print(result)
# Out:
#                                                release_date  \
# title
# NaN                                                       1
# NaN                                                      12
# Passage of Venus                                 1874-12-09
# Sallie Gardner at a Gallop                       1878-06-14
# Buffalo Running                                  1883-11-19
# ...                                                     ...
# Engineering Red                                         NaN
# All Superheroes Must Die 2: The Last Superhero          NaN
# The Land Where the Blues Began                          NaN
# Aprel                                                   NaN
# Subdue                                                  NaN
#
#                                                                           budget  \
# title
# NaN                                             /ff9qCepilowshEtG2GYWwzt2bs4.jpg
# ...

# %% [markdown]
# ## R.access those movies released after 1995-01-01

# %%
result=small_df[small_df['release_date']>'1995-01-01']
print("dataframe based on release date >'1995-01-01'")
print(result)
# Out:
# dataframe based on release date >'1995-01-01'
#                             release_date    budget      revenue  runtime
# title
# Toy Story                     1995-10-30  30000000  373554033.0     81.0
# Jumanji                       1995-12-15  65000000  262797249.0    104.0
# Grumpier Old Men              1995-12-22         0          0.0    101.0
# Waiting to Exhale             1995-12-22  16000000   81452156.0    127.0
# Father of the Bride Part II   1995-02-10         0   76578911.0    106.0
# ...                                  ...       ...          ...      ...
# Shadow of the Blair Witch     2000-10-22         0          0.0     45.0
# The Burkittsville 7           2000-10-03         0          0.0     30.0
# Century of Birthing           2011-11-17         0          0.0    360.0
# Betrayal                      2003-08-01         0          0.0     90.0
# Queerama                      2017-06-09         0          0.0     75.0
#
# [27294 rows x 4 columns]

# %% [markdown]
# ## T.sort movies on runtime in descending order

# %%
result=small_df.sort_values("runtime",ascending=False)
print("dataframe sort on runtime")
print(result)
# Out:
# dataframe sort on runtime
#                                release_date budget  revenue  runtime
# title
# Centennial                       1978-10-01      0      0.0   1256.0
# Baseball                         1994-09-18      0      0.0   1140.0
# Jazz                             2001-01-09      0      0.0   1140.0
# Berlin Alexanderplatz            1980-08-28      0      0.0    931.0
# Heimat: A Chronicle of Germany   1984-09-16      0      0.0    925.0
# ...                                     ...    ...      ...      ...
# Villa Henriette                  2004-12-02      0      0.0      NaN
# Między nami dobrze jest          2014-08-01      0      0.0      NaN
# Ostatni dzwonek                  1989-10-27      0      0.0      NaN
# Simbad e il califfo di Bagdad    1973-07-22      0      0.0      NaN
# Aprel                                   NaN      0      0.0      NaN
#
# [45466 rows x 4 columns]

# %% [markdown]
# ## U.get the longest runtime and shortest runtime

# %%
small_df=df[['runtime']]
run_time=small_df['runtime']
print(small_df)
# Out:
#                              runtime
# title
# Toy Story                       81.0
# Jumanji                        104.0
# Grumpier Old Men               101.0
# Waiting to Exhale              127.0
# Father of the Bride Part II    106.0
# ...                              ...
# Subdue                          90.0
# Century of Birthing            360.0
# Betrayal                        90.0
# Satan Triumphant                87.0
# Queerama                        75.0
#
# [45466 rows x 1 columns]

# %% [markdown]
# ## V.calculate the number of votes garnerd by the 70% movie

# %%
result=df['vote_count'].quantile(0.70)
print(result)
# Out:
# 25.0

# %% [markdown]
# ## W. display themovies ('title,runtime) longer than 30 min and shorter then 360 min

# %%
result=small_df[(small_df['runtime']>=30) & (small_df['runtime']<=360)]
print(result)
# Out:
#                              runtime
# title
# Toy Story                       81.0
# Jumanji                        104.0
# Grumpier Old Men               101.0
# Waiting to Exhale              127.0
# Father of the Bride Part II    106.0
# ...                              ...
# Subdue                          90.0
# Century of Birthing            360.0
# Betrayal                        90.0
# Satan Triumphant                87.0
# Queerama                        75.0
#
# [42297 rows x 1 columns]

# %% [markdown]
# ## X.display the movies (title , number of values) of that received specified number of

# %%
n=500
small_df=df[['vote_count']]
result=small_df[small_df['vote_count']>=n]
print(result)
# Out:
#                                vote_count
# title
# Toy Story                          5415.0
# Jumanji                            2413.0
# Heat                               1886.0
# GoldenEye                          1194.0
# Casino                             1343.0
# ...                                   ...
# What Happened to Monday             598.0
# Atomic Blonde                       748.0
# Dunkirk                            2712.0
# Transformers: The Last Knight      1440.0
# The Dark Tower                      688.0
#
# [2056 rows x 1 columns]

# %%
df.reset_index()
# Out:
#        index  adult                              belongs_to_collection  \
# 0          0  False  {'id': 10194, 'name': 'Toy Story Collection', ...
# 1          1  False                                                NaN
# 2          2  False  {'id': 119050, 'name': 'Grumpy Old Men Collect...
# 3          3  False                                                NaN
# 4          4  False  {'id': 96871, 'name': 'Father of the Bride Col...
# ...      ...    ...                                                ...
# 45461  45461  False                                                NaN
# 45462  45462  False                                                NaN
# 45463  45463  False                                                NaN
# 45464  45464  False                                                NaN
# 45465  45465  False                                                NaN
#
#          budget                                             genres  \
# ...

# %%
df.iloc[2,6]
# Out:
# 'tt0113228'

# %%
df.set_index('title')
# Out:
#                              adult  \
# title
# Toy Story                    False
# Jumanji                      False
# Grumpier Old Men             False
# Waiting to Exhale            False
# Father of the Bride Part II  False
# ...                            ...
# Subdue                       False
# Century of Birthing          False
# Betrayal                     False
# Satan Triumphant             False
# Queerama                     False
#
#                                                          belongs_to_collection  \
# title
# Toy Story                    {'id': 10194, 'name': 'Toy Story Collection', ...
# Jumanji                                                                    NaN
# Grumpier Old Men             {'id': 119050, 'name': 'Grumpy Old Men Collect...
# Waiting to Exhale                                                          NaN
# Father of the Bride Part II  {'id': 96871, 'name': 'Father of the Bride Col...
# ...

# %%
df.loc['Toy Story','Jumanji']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3.3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3.3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3.3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Jumanji'
#
# The above exception was the direct cause of the following exception:
#
# ...
